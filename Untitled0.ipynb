# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayrarames/StrukturDataD-Pertemuan1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# definisikan lis kosong untuk menyimpan angka

# %%
list = []

# %% [markdown]
# input 10 angka

# %%
my_list = []
for i in range(10):
    angka = int(input("Masukkan angka: "))
    my_list.append(angka)
# Out:
# Masukkan angka: 3
# Masukkan angka: 5
# Masukkan angka: 7
# Masukkan angka: 8
# Masukkan angka: 9
# Masukkan angka: 2
# Masukkan angka: 4
# Masukkan angka: 5
# Masukkan angka: 6
# Masukkan angka: 7
